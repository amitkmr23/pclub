# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("/content/house_train.csv")

# %%
df.shape
# Out:
# (1460, 81)

# %%
df.describe()

# %%
df.head()
# Out:
#    Id  SalePrice  OverallQual  GrLivArea  GarageCars  GarageArea  TotalBsmtSF  \
# 0   1     208500            7       1710           2         548          856
# 1   2     181500            6       1262           2         460         1262
# 2   3     223500            7       1786           2         608          920
# 3   4     140000            7       1717           3         642          756
# 4   5     250000            8       2198           3         836         1145
#
#    1stFlrSF  FullBath  TotRmsAbvGrd  ...  LotFrontage  WoodDeckSF  2ndFlrSF  \
# 0       856         2             8  ...         65.0           0       854
# 1      1262         2             6  ...         80.0         298         0
# 2       920         2             6  ...         68.0           0       866
# 3       961         1             7  ...         60.0           0       756
# 4      1145         2             9  ...         84.0         192      1053
#
# ...

# %%
df.info()

# %%
df.sample(30)

# %%
df.info()

# %%
df.isnull().mean()

# %%
corr_matrix = df.corr()
corr_matrix['SalePrice'].sort_values(ascending=False)

# %%
df

# %%
df.sample(45)

# %%
corr_matrix = df.corr()
corr_matrix['SalePrice'].sort_values(ascending=False)

# %%
df = df[['Id','SalePrice','OverallQual',
'GrLivArea',
'GarageCars',
'GarageArea',
'TotalBsmtSF',
'1stFlrSF',
'FullBath',
'TotRmsAbvGrd',
'YearBuilt',
'YearRemodAdd',
'GarageYrBlt',
'MasVnrArea',
'Fireplaces',
'BsmtFinSF1',
'LotFrontage',
'WoodDeckSF',
'2ndFlrSF',
'OpenPorchSF',
'HalfBath',
'LotArea',
'BsmtFullBath',
'BsmtUnfSF',
'BedroomAbvGr',
'KitchenAbvGr']]

# %%
df

# %%
df.sample(45)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 26 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Id            1460 non-null   int64
#  1   SalePrice     1460 non-null   int64
#  2   OverallQual   1460 non-null   int64
#  3   GrLivArea     1460 non-null   int64
#  4   GarageCars    1460 non-null   int64
#  5   GarageArea    1460 non-null   int64
#  6   TotalBsmtSF   1460 non-null   int64
#  7   1stFlrSF      1460 non-null   int64
#  8   FullBath      1460 non-null   int64
#  9   TotRmsAbvGrd  1460 non-null   int64
#  10  YearBuilt     1460 non-null   int64
#  11  YearRemodAdd  1460 non-null   int64
#  12  GarageYrBlt   1379 non-null   float64
#  13  MasVnrArea    1452 non-null   float64
#  14  Fireplaces    1460 non-null   int64
#  15  BsmtFinSF1    1460 non-null   int64
#  16  LotFrontage   1201 non-null   float64
#  17  WoodDeckSF    1460 non-null   int64
# ...

# %%
# !pip install ydata-profiling

# %%
# from ydata_profiling import ProfileReport
# prof= ProfileReport(df)
# prof.to_file(output_file='pclub.html')

# %%
# !pip install typing_extensions

# %%
import seaborn as sns

# %%
sns.countplot(df,x='LotArea')
# Out:
# <Axes: xlabel='LotArea', ylabel='count'>

# %%
df['BsmtFullBath'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='BsmtFullBath'>

# %%
plt.hist(df['TotalBsmtSF'])
# Out:
# (array([121., 907., 372.,  52.,   3.,   4.,   0.,   0.,   0.,   1.]),
#  array([   0.,  611., 1222., 1833., 2444., 3055., 3666., 4277., 4888.,
#         5499., 6110.]),
#  <BarContainer object of 10 artists>)

# %%
sns.boxplot(df,x='GarageArea')
# Out:
# <Axes: xlabel='GarageArea'>

# %%
sns.scatterplot(data=df,x='BsmtFullBath',y='BedroomAbvGr',hue='HalfBath',style='2ndFlrSF',size='LotFrontage')
# Out:
# <Axes: xlabel='BsmtFullBath', ylabel='BedroomAbvGr'>

# %%
sns.barplot(df,x='1stFlrSF',y='FullBath',hue='MasVnrArea')

# %%
sns.pairplot(df)

# %%
from sklearn.model_selection import train_test_split

# %%
x=df.drop('SalePrice',axis=1)
y=df['SalePrice']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer

# %%
transform=ColumnTransformer(transformers=[
    ('tnf1',OneHotEncoder(sparse=False,drop='first'),['Id']),
    ('tnf2',SimpleImputer(),['GarageYrBlt','MasVnrArea','LotFrontage'])
],remainder='passthrough')

# %%
hey=transform.fit_transform(x_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
heya=transform.fit_transform(x_test)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
# from sklearn.neighbors import KNeighborsClassifier

# %%
#  model=KNeighborsClassifier()

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier(random_state=0)

# %%
 clf.fit(hey,y_train)
# Out:
# DecisionTreeClassifier(random_state=0)

# %%
from sklearn.metrics import accuracy_score

# %%
prediction=clf.predict(hey)
accuracy=accuracy_score(prediction,y_train)

# %%
prediction
# Out:
# array([145000, 178000,  85000, ..., 115000, 189950, 174000])

# %%
accuracy
# Out:
# 1.0
